# %% [markdown]
# # HOW MUCH WOULD A HOUSE IN AMES, IOWA COST?
#
# <i>Hemshree Mangrola,<br>
#     Northeastern University</i>
# <br>
# <br>
# ***
#
#
# ## Abstract
#
# Compelled to grow and propelled to be mainstream, predictive technology is a commonplace and affects everyone everyday. It impacts our expectations as we drive, eat, shop, vote, see a doctor, communicate, watch television, listen to music, borrow oe even steal. Making such predictions poses a tough challenge. Each prediction depends on various factors. And to keep all these factors we have data, which is considered as the most potent unnatural resource of the modern society.
#
# The purpose of predictive modeling here was to identify the factors that demonstrated significant statistical correlations with House Prices. <br>
#
# <br>
# <br>
# ***
#
#
# ## Methodology
#
# <img src="https://github.com/hmangrola/Predicting-House-Prices-Ames-Iowa/raw/83f7dc3f9bd859c89ea9e63106ae229bc4ed5d82/images/Introduction.png"/>
#
#
# ### Data Source
#
# The dataset used in this project was collected and made available to public by <b>Dean De Cock</b>.
# [1]This dataset is inspired from the Boston Housing dataset which had only 506 datapoints with 14 variables and it served as a great predictive model project to work on. The data set contains 2930 observations and a large number of explanatory
# variables (23 nominal, 23 ordinal, 14 discrete, and 20 continuous) involved in assessing home values.
#
# >#### Details of the population selected for building predictive model
#
# > The dataset has information of house details and prices of sales of houses from year the 2006 to year the 2010 in Ames, Iowa in The United States of America. The house prices vary for same type of house in each city or town and hence knowing more about Ames was very important.[2] Ames is a city located in the central part of Story County, Iowa, with an area of 23.5 sq miles. The historical city had an population of 59,000 in 2010 with 84.3% white population. Ames is home of Iowa State University of Science and Technology, a public land-grant and space-grant research university which employees 15,500 people in the city. It has 37% lower crime rate thaan the national average and a pleasant weather through the year. The city has lower median earning compared to the national average and on the same hand, 16% lower unemployement rate than the national average.
# <br>
#
# ### The studies, analysis and the hypothesis generation can be found:
# [Knowing Ames, Iowa, Data Analysis and Hypothesis generation](https://github.com/hmangrola/Predicting-House-Prices-Ames-Iowa/blob/master/Knowing%20Ames%2C%20Data%20Analysis%20and%20Hypothesis%20generation.ipynb)
#
# <br>
# <br>
# ***
#
# ### Clean, Prepare and Manipulate data
#
# >Python pre-processing and pandas library along python's inbuilt capability helps in understanding the data, manipulating it and preparing it for data modelling.
#
# >>_From the code book:_ .isnull() helps us in getting count or sum of the number of null values in each column of the dataset
#
#
# <img src ='https://github.com/hmangrola/Predicting-House-Prices-Ames-Iowa/raw/83f7dc3f9bd859c89ea9e63106ae229bc4ed5d82/images/missing_values.PNG'>
#
# <br>
#
# >>_From the code book:_ seaborn and matplotlib helps in visualising our data patterns and understanding the necessary manipulations
#
# <img src ='https://github.com/hmangrola/Predicting-House-Prices-Ames-Iowa/raw/83f7dc3f9bd859c89ea9e63106ae229bc4ed5d82/images/plot.PNG'>
#
# <br>
#
# >>_From the code book:_ label encoder helps in manipulating categorical variables to numerical which can be used by all the predictive model algorithms.
#
# <img src='https://github.com/hmangrola/Predicting-House-Prices-Ames-Iowa/raw/83f7dc3f9bd859c89ea9e63106ae229bc4ed5d82/images/manipulate.PNG'>
#
# ### The data preprocessing for this dataset can be found:
#  [Data Pre-processing](https://github.com/hmangrola/Predicting-House-Prices-Ames-Iowa/blob/master/Pre-Processing%20the%20dataset.ipynb)__
#
# <br>
# <br>
# ***
#
# ### Train and test models
#
# The predictive model involves using regression analysis. I have built various models and compare the results to understand the factors and also built a more stable model which can help in predicting the house prices.
#
#
# >### -  __Model 1: Simple Linear Regression between selected houses area __<br>
# >The author of the dataset, Dean De Cock, suggested a similar predictive model in his paper. Observing the linear relation between living area and the sale price in the dataset I decided on work on the linear model with houses having areas less than 2500 square feet for my first model. Total Area of the house, according to me plays the most important role in deciding the sale price. <br>
# >So what is linear regression?<br>
# ><p>Linear regression in simple term allows us to summarize and study relationships between two continuous variables(dependent and independent). The equation for simple linear regression is written as:</p>
# >>$$
# Y = a + bX
# $$
#
# >where Y is the dependent variable which can be deteremined by independent variable X and coefficient b. The coefficient tells us how a unit change in X affects the unit change in Y. <br> I have tried to understand the linear relation between living area and Sale Price.
#
# <img src="https://github.com/hmangrola/Predicting-House-Prices-Ames-Iowa/raw/83f7dc3f9bd859c89ea9e63106ae229bc4ed5d82/images/Simple_Linear_Regression.PNG">
#
# >The above graph example shows a linear relation between degree Fahrenhiet and degree Celcius.
#
# >The linear relationship between living area and sale price of the house exist but the accuracy (which is 49%) of the model suggests that there are other factors which more precisely determines the linear relaionship with the Sale Price of the house.
# <br>
# <br>
# >>From the code book
#
#
# <img src="https://github.com/hmangrola/Predicting-House-Prices-Ames-Iowa/raw/83f7dc3f9bd859c89ea9e63106ae229bc4ed5d82/images/Simple%20linear%20regression.PNG">
#
# >I decided to add basement area to the predicting factor; the living area with the basement area added 11% accuracy to the linear model. This shows, the generated hypothesis where we gave a priority to basement area and living area is correct.
# <br>
# <br>
# >>From the code book
#
#
#
# <img src="https://github.com/hmangrola/Predicting-House-Prices-Ames-Iowa/raw/83f7dc3f9bd859c89ea9e63106ae229bc4ed5d82/images/SLR.PNG">
# <br>
# <br>
#
#
# >### -  __Model 2: Ridge Regression __<br>
# >When we perform multiple linear regression, there are chances of multicollinearity between variables. This affects the model prediction; to handle this a penalizing term is introduced to linear model.<br>
#
# ><p>There is no collineaity between basement area and living area but I considered using ridge regression to the second linear model and see hoe the penalizing factors affect the accuracy of the model. </p>
# <br>
#
# >>From the code book<br>
# <img src="https://github.com/hmangrola/Predicting-House-Prices-Ames-Iowa/raw/83f7dc3f9bd859c89ea9e63106ae229bc4ed5d82/images/ridge%201.PNG">
#
# >I decided to add all the selected factors of the hypothesis to the predicting factor; the overall model accuracy increased to 80% and this looks like a more better model than the basic linear model.
# <br>
# <br>
# >>From the code book
# <img src="https://github.com/hmangrola/Predicting-House-Prices-Ames-Iowa/raw/83f7dc3f9bd859c89ea9e63106ae229bc4ed5d82/images/ridge%202.PNG">
# <br>
# <br>
#
#
# >### -  __Model 3: Decision Tree Regression Model __<br>
# >[4]Decision tree builds regression or classification models in the form of a tree structure. It brakes down a dataset into smaller and smaller subsets while at the same time an associated decision tree is incrementally developed. The final result is a tree with decision nodes and leaf nodes. A decision node (e.g., Outlook) has two or more branches (e.g., Sunny, Overcast and Rainy), each representing values for the attribute tested. Leaf node (e.g., Hours Played) represents a decision on the numerical target. The topmost decision node in a tree which corresponds to the best predictor called root node. Decision trees can handle both categorical and numerical data.<br>
#
#
# ><img src="https://github.com/hmangrola/Predicting-House-Prices-Ames-Iowa/raw/83f7dc3f9bd859c89ea9e63106ae229bc4ed5d82/images/decisiontree_example.PNG">
#
#
# ><p>I have used all the features from the generated hypothesis for the decision tree regression model. </p>
# <br>
#
# >>From the code book
#
#
# <img src="https://github.com/hmangrola/Predicting-House-Prices-Ames-Iowa/raw/83f7dc3f9bd859c89ea9e63106ae229bc4ed5d82/images/decisionTree.PNG">
#
# >The cross validation score for the training set gives us 76% accuracy with coefficients showing high dependency for the sale price of the house on garage cars followed by living and basement area.
# <br>
# <br>
# >>From the code book
#
#
#
# <img src="https://github.com/hmangrola/Predicting-House-Prices-Ames-Iowa/raw/83f7dc3f9bd859c89ea9e63106ae229bc4ed5d82/images/decisiontree_feature.PNG">
# <br>
# <br>
#
# >### -  __Model 4: Random Forest Regression Model __<br>
# >Random forest builds multiple decision trees and merges them together to get a more accurate and stable prediction.<br>
#
#
# ><img src="https://github.com/hmangrola/Predicting-House-Prices-Ames-Iowa/raw/83f7dc3f9bd859c89ea9e63106ae229bc4ed5d82/images/randomForest_example.PNG">
#
#
# ><p>We observed in decision tree model that garage car had more influence on the sale price according to the algorithm and so I decided to take all the features except garage cars from the generated hypothesis for the decision tree regression model. </p>
# <br>
#
# >>From the code book
#
#
# <img src="https://github.com/hmangrola/Predicting-House-Prices-Ames-Iowa/raw/83f7dc3f9bd859c89ea9e63106ae229bc4ed5d82/images/randomForest.PNG">
#
# >The cross validation score for the training set gives us 81% accuracy with coefficients showing high dependency for the sale price of the house on living and basement area.
# <br>
# <br>
# >>From the code book
#
#
#
# <img src="https://github.com/hmangrola/Predicting-House-Prices-Ames-Iowa/raw/83f7dc3f9bd859c89ea9e63106ae229bc4ed5d82/images/randomForest_feature.PNG">
# <br>
# <br>
# >### -  __Model 5: Multiple linear regression reloaded __<br>
#
#
# ><p>Observing that the garage cars also plays an important role in formulating the sale price, I wanted to learn how garage cars, basement area and living area together influence the sale price </p>
# <br>
#
# >>From the code book
#
#
# <img src="https://github.com/hmangrola/Predicting-House-Prices-Ames-Iowa/raw/83f7dc3f9bd859c89ea9e63106ae229bc4ed5d82/images/linear_reloaded.PNG">
#
# <br>
# <br>
# ***
#
#
#
# >### K fold Cross Validation technique for model validation
#
# The random sub-sampling cross-validation method [4] was used to test the accuracy of the predictive models. This form of validation runs a model multiple times in randomized simulation environments and averages the results. The primary objective of validation was to confirm that the predicted house prices were correlated with the factors selected.
#
#
# <img src="https://github.com/hmangrola/Predicting-House-Prices-Ames-Iowa/raw/83f7dc3f9bd859c89ea9e63106ae229bc4ed5d82/images/cross_validation.PNG">
#
#
# ### The code for predictive models can be found:
# [Test and Train the model](https://github.com/hmangrola/Predicting-House-Prices-Ames-Iowa/blob/master/Predictive%20modelling.ipynb)
#
# <br>
# <br>
# ***
#
# ### Conclusion
#
# <p>The prediction models built in this project utilised certain factors of the house and the location. It can be said from the models that sale prices are highly influenced by the area of the house, the basement area and the number of cars that can be accomodated in the housing. These proved to be most influencial as the model attained 67% accuracy right with these three factors. The other factors like neighborhood, house and building type followed in the influencial factors list.The best model observed 81% accuracy on cross validation score which according to me has a scope of improvement.</p>
#
# <p> A software version of the project can help the marketers predict the prices just on few selected factors used here. This project does not have modern data, which means the changes in neighborhood, building and house type preference over the period of 2010 - 2018 could have changed and can give us lower accuracy. If Ames had observed great economic growth over the period the model would need more data to learn and improve the model for better predictions.  </p>
# <br>
#
# The project is available for use and download [Complete Project](https://github.com/hmangrola/Predicting-House-Prices-Ames-Iowa)
#
# <br>
# ***
#
#
# ### References
#
# [1] http://ww2.amstat.org/publications/jse/v19n3/decock.pdf<br><br>
# [2] https://en.wikipedia.org/wiki/Ames,_Iowa<br><br>
# [3] http://robotics.stanford.edu/~ronnyk/accEst.pdf<br><br>
# [4] http://www.saedsayad.com/<br><br>
# [5] https://databricks.com/blog/2015/01/21/random-forests-and-boosting-in-mllib.html<br><br>
# [6] https://onlinecourses.science.psu.edu/stat501/node/2<br><br>
# Python for Data Analysis, O'Reilly publications, first edition<br><br>
# Statisctics for Business Analytics - Udemy course by Kirill Eremenko<br><br>
# Machine Learning A-Z: Hands-on with Python and R by Kirill Eremenko<br><br>
# Khan Academy - for statistics<br><br>
