# %% [markdown]
# ## Introduction
#
#
# Like other types of assets, the price of real estate is determined by the observed and unobserved attributes of the asset. Houses exhibit unobserved heterogeneity across various dimensions. Same sized bedrooms can be valued differently depending on the location of the window. The topography of same sized lots can affect the value of the property.Neighborhood amenities, like nearby schools and parks, are important determinants of property prices. While no two houses in general are alike, houses have been priced based on what appraisers or brokers refer to as comparables, observationally similar houses that were recently
# sold in the same or nearby neighborhood. Pricing adjustments are made to reflect the differences between the house of interest and the comparable houses. In other words, the price of a house takes into account the price information of other houses.
# <br>
# <br>
# ***
#
#
# ## Dataset
#
# I have decided to work on -
# <b>House Prices: Advanced Regression Techniques</b> - A Kaggle competition and the dataset can be accessed from https://www.kaggle.com/c/house-prices-advanced-regression-techniques/data
#
# The data set describes the sale of individual residential property in Ames, Iowa from 2006 to 2010. The data set contains 2930 observations and a large number of explanatory variables (23 nominal, 23 ordinal, 14 discrete, and 20 continuous) involved in assessing home values.
#
# The explanation of the dataset can be found on kaggle
# <br>
# <br>
# ***
#
#
# ## Working on a predictive model
#
# When we start working on a predictive model, the <b>first step</b> should always be understanding the business objective. Here, in general, the Predictive analysis of house prices helps us in increasing customer experiences, understanding market and also financial modeling. <b>Second step,</b> how will this model help in understanding the market in a long term? I aim to built the model such that adding data to it can help predicting the house prices at any given time (given that, the data belongs to one city). I will also focus on understanding some unobserved features that impact the Sale price of the house. <b>Third step,</b> selecting data for modeling; here, I have a dataset to work on with all the related attributes impacting the sale price of the house. <b>Fourth step,</b> preparing the data. Data we collect is usually not the correct format and has many missing values, we have to perform initial analysis to know the data and remove discrepancies by transforming variables and values. <b>Fifth step,</b> model selection and training model. (from the results obtained, we can further alter the model to built a more robust and scalable model) <b>Sixth step,</b> validating the model we can score and predict the test sample and also compare the accuracy of various models.
#
# <b>Note:</b> Here, I have worked on generating the hypothesis (this might lead to leaving back some variables that should be taken into consideration and hence, I read a few articles on Zillow and trulia to guide me through and take the best factors that can impact the Sale Prices of the house.)
# <br>
# <br>
# ***
#
#
# ## Knowing Ames, Iowa
#
# When we try to predict the price of the house, the first most important factor is the location of the house; the location includes, Country, State and the city. Here, since we are refering to only Ames in Iowa, I have reffered to various real estate and crime data sites to understand the demographics, weather, income and crimes in Ames.
# https://github.com/hemshreemangrola/House-Pricing/blob/master/Knowing%20Ames%2C%20Iowa.pptx
# <br>
# <br>
# ***
#
#
# ## Hypothesis Generation
#
# What influences the Sale Prices?
#
# The major factors influencing the house prices according to me are:
# 1.  The geographic location of the house, taking the granularity of zip codes for geographic location
# 2.  The neighbourhood of the house
# 3.  The number of bedrooms, bathrooms and balcony
# 4.  The area of the house
# 5.  Number of floors
# 6.  Parking and basement area
# 7.  Furnished or unfurnished
# 8.  Year of construction
# 9.  Utilities in the house
# 10. The amenities near to the house (school, parks, etc)
# <br>
# <br>
# ***
#
#
# ## Stats from the past!
#
# I have referred to Zillow Analysis 2016 and compared it to the analysis generated from the data set. I have used tableau to perform basic exploratory data analysis.
#
# https://github.com/hemshreemangrola/House-Pricing/blob/master/House%20Prices.pptx
#
#
# Now, I have checked the dataset with the available variables and compare it to the generated hypothesis.
# <br>
# <br>
# ***
#
#
# ## Comparing the dataset with my generated hypothesis
#
# We can draw the following data points from the dataset according to my hypothesis:
#
# >#### 1. Geographic location:
# >The geographic location accroding to the hypothesis can be taken up with the Historic town of Ames, Iowa
#
# >#### 2. Neighbourhood:
# >The nieghbourhood gives us details like the location in the city/town. The <i>neighbourhood</i> factor in the dataset provides us with the information we aim to focus on and <i>Zoning classification</i> adds more information to the data of neighbourhood.
#
# >#### 3. Number of bedrooms, bathrooms and Balcony:
# >The number of bedrooms, bathrooms and balcony can be determined in the dataset from the data points <i>Full Bath, Bedrooms, Halfbath</i>. More the number of rooms with the increased surface area, more the sale price of the house.
#
# >#### 4. The area of the house
# >Area of the house includes the area of all the floors, garage and backyard or frontyard. The data points determining these values are <i>Garage Area, Firstfloor square feet, secondfloor square feet, wood porch area, enclosed porch area, open porch area, screen porch, pool area</i>
#
# >#### 5. Number of floors
# >Number of floors allows privacy and hence is being preffered
#
# >#### 6. Parking and basement area
# >The area of parking and basement area have been incuded in the total area
#
# >#### 7. Furnished and unfurnished
# >This feature determines whether the bedrooms are furnished with beds and neccessary furniture or not. The dataset does not describe this feature
#
# >#### 8. Year of construction
# >The data point <i>YearBuilt and Garage YearBuilt</i> determines the year in which the house was built. This overall affects the sales price of the house
#
# >#### 9. Utilities
# >Utilities in the dataset includes points: <i>Heating system, electrical system, central air, number of fireplace and utilities</i>
#
# According to the first generated hypotesis, I will perform the analysis and built a predictive model.
#
# >### Ading to the Hypothesis
#
#
# 1. Garage Area
# 2. Garage cars
# 3. Total rooms above ground
# 4. Full bath
# 5. Ground living area
# 6. First floor surface area
# 7. Total Basement surface area
# 8. Overall quality
#
# Adding the two more features to our hypothesis selected features, we will include <i>garage car, overall quality and ground living area</i> for our analysis and predictive model generation
# <br>
# <br>
# ***
#
#
# ### Final Features for model generation
#
# These features will evolve, some will be removed and some would be added to the model according to the errors and prediction made by the model.
# Features to work with (step 1)
#
#
# <b>Neighborhood</b>: Physical locations within Ames city limits
#
#        Blmngtn	Bloomington Heights
#        Blueste	Bluestem
#        BrDale	Briardale
#        BrkSide	Brookside
#        ClearCr	Clear Creek
#        CollgCr	College Creek
#        Crawfor	Crawford
#        Edwards	Edwards
#        Gilbert	Gilbert
#        IDOTRR	Iowa DOT and Rail Road
#        MeadowV	Meadow Village
#        Mitchel	Mitchell
#        Names	North Ames
#        NoRidge	Northridge
#        NPkVill	Northpark Villa
#        NridgHt	Northridge Heights
#        NWAmes	Northwest Ames
#        OldTown	Old Town
#        SWISU	South & West of Iowa State University
#        Sawyer	Sawyer
#        SawyerW	Sawyer West
#        Somerst	Somerset
#        StoneBr	Stone Brook
#        Timber	Timberland
#        Veenker	Veenker
#
# <b>BldgType</b>: Type of dwelling
#
#        1Fam	Single-family Detached
#        2FmCon	Two-family Conversion; originally built as one-family dwelling
#        Duplx	Duplex
#        TwnhsE	Townhouse End Unit
#        TwnhsI	Townhouse Inside Unit
#
# <b>HouseStyle</b>: Style of dwelling
#
#        1Story	One story
#        1.5Fin	One and one-half story: 2nd level finished
#        1.5Unf	One and one-half story: 2nd level unfinished
#        2Story	Two story
#        2.5Fin	Two and one-half story: 2nd level finished
#        2.5Unf	Two and one-half story: 2nd level unfinished
#        SFoyer	Split Foyer
#        SLvl	Split Level
#
# <b>YearBuilt</b>: Original construction date
#
#
# <b>YearRemodAdd</b>: Remodel date (same as construction date if no remodeling or additions)
#
#
# <b>TotalBsmtSF</b>: Total square feet of basement area
#
#
# <b>CentralAir</b>: Central air conditioning
#
#        N	No
#        Y	Yes
#
# <b>Garage Cars</b>: Number of cars accomodated in the garage
#
#
# <b>1stFlrSF</b>: First Floor square feet
#
#
# <b>2ndFlrSF</b>: Second floor square feet
#
#
# <b>GrLivArea</b>: Above grade (ground) living area square feet
#
#
# <b>FullBath</b>: Full bathrooms above grade
#
#
# <b>HalfBath</b>: Half baths above grade
#
#
# <b>Kitchen</b>: Kitchens above grade
#
#
# <b>TotRmsAbvGrd</b>: Total rooms above grade (does not include bathrooms)
#
#
# <b>YrSold</b>: Year Sold (YYYY)
# <br>
# <br>
# ***
#
#
# ## References
#
# https://www.trulia.com/real_estate/Ames-Iowa/
#
# http://www.areavibes.com/ames-ia/
#
# https://www.zillow.com/research/zillow-group-report-2016-13279/
#
# https://spotcrime.com/
#
# https://web.stanford.edu/~yongslee/HSSPOPE.pdf
#
# Predictive Analytics by Eric Siegel - This book has been a real inspiration and has helped me think with a better perspective
